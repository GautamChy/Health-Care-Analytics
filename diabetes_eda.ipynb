# %% [markdown]
# 1. The datasets consist of several medical predictor (independent) variables and one target (dependent) variable, Outcome. Independent variables include the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %% [markdown]
# 2) Data Collection
# - The data consists of 768 columns and 9 rows

# %% [markdown]
# Steps We Are Going to Follow
# - Data Cleaning
# - Exploratory Data Analysis
# - Appropriate visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Load dataset (after dowloading from kaggle)
df = pd.read_csv('diabetes.csv')

# %%
# Checking top 5 value.
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# # Data Cleaning & Preprocessing

# %%
# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Basic info
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# checking top 2 value
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
# Checking Missing Values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# checking class balance
df['Age'].value_counts()
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 36    16
# 38    16
# 32    16
# 45    15
# 34    14
# 46    13
# 40    13
# 43    13
# 39    12
# 35    10
# 44     8
# 50     8
# 51     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 60     5
# 53     5
# 57     5
# 48     5
# 63     4
# 66     4
# 55     4
# 62     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64

# %%
# checing unique values
df['Age'].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68])

# %%
# checking null value
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Delete a single column or drop sigle column
df = df.drop('SkinThickness', axis=1, inplace = True)

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Replacing first parameter by second parameter
df['SkinThickness'] = df['SkinThickness'].replace(35, np.nan)
# To remove string value
# df['SkinThickness'] = df['SkinThickness'].str.replace('string value', 'added new numerical value or string value ')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72            NaN        0  33.6
# 1            1       85             66           29.0        0  26.6
# 2            8      183             64            NaN        0  23.3
# 3            1       89             66           23.0       94  28.1
# 4            0      137             40            NaN      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# To change into float
df['SkinThickness'] = df['SkinThickness'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             526 non-null    float64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 54.1 KB

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72            NaN        0  33.6
# 1            1       85             66           29.0        0  26.6
# 2            8      183             64            NaN        0  23.3
# 3            1       89             66           23.0       94  28.1
# 4            0      137             40            NaN      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Outcome distribution
df['Outcome'].value_counts(normalize = True) * 100
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: proportion, dtype: float64

# %%
# Compare means by outcome
df.groupby('Glucose').mean()
# Out:
#          Pregnancies  BloodPressure  SkinThickness     Insulin        BMI  \
# Glucose
# 0           2.800000      67.600000          28.25    4.600000  32.880000
# 44          5.000000      62.000000            NaN    0.000000  25.000000
# 56          2.000000      56.000000          28.00   45.000000  24.200000
# 57          4.500000      70.000000          37.00    0.000000  27.250000
# 61          3.000000      82.000000          28.00    0.000000  34.400000
# ...              ...            ...            ...         ...        ...
# 195         6.500000      70.000000          33.00   72.500000  28.000000
# 196         5.333333      80.666667          32.50  176.333333  37.933333
# 197         4.000000      71.000000          61.00  321.750000  31.950000
# 198         0.000000      66.000000          32.00  274.000000  41.300000
# 199         1.000000      76.000000          43.00    0.000000  42.900000
#
#          DiabetesPedigreeFunction        Age  Outcome
# Glucose
# ...

# %% [markdown]
# # DUPLICATE

# %% [markdown]
# 1. Check If duplicate exists

# %%
# Total number of duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# True/False for each row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %% [markdown]
# 2. View the actual duplicate rows

# %%
# Show all duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Show duplicates INCLUDING the first occurence
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# 3. Check duplicates on columns

# %%
# Duplicates based on one column
df.duplicated (subset=['Glucose']).sum()
# Out:
# np.int64(632)

# %%
# Duppicates based on multiple columns
df.duplicated(subset=['Glucose','BMI','Age']).sum()
# Out:
# np.int64(1)

# %% [markdown]
# 4. Remove duplicates

# %%
# Remove dupicate rows (Keep first occurence)
df.drop_duplicates(inplace = True)

# %%
# Remove duplicates based on specific columns
df.drop_duplicates(subset=['Glucose','Age'], inplace = True)

# %% [markdown]
# 5. Verify after removing duplicates

# %%
# Confirm no duplicates remain
print('Duplicates remianing:', df.duplicated().sum())
# Out:
# Duplicates remianing: 0

# %%
# Check shape before and after
print('Shape after removing duplicates:', df.shape)
# Out:
# Shape after removing duplicates: (664, 9)

# %% [markdown]
# # VISUALIZATIONS DIAGRAM

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Top 10 Age
Age = pd.DataFrame(df['Age'].value_counts())

print(Age.head(10))
# Out:
#      count
# Age
# 22      50
# 21      42
# 25      41
# 24      35
# 23      32
# 27      31
# 26      29
# 28      28
# 29      26
# 31      23

# %% [markdown]
# # BAR CHART

# %%
top_10_age = Age.head(10)
top_10_age.plot(kind = 'bar', figsize=(10,6))
plt.title('Top 10 Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 1. Outcome Distribution (Count Plot)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Outcome', data=df, palette='Set2')
plt.title('Diabetes Outcome Distribution')
plt.xticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.legend(['Non-Diabetic','Diabetic'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
outcome_counts = df['Outcome'].value_counts()

plt.pie(outcome_counts,
        labels=['Non-Diabetic', 'Diabetic'],
        autopct='%1.1f%%',
        colors=['#66b3ff', '#ff6666'],
        explode=(0.05, 0.05),
        startangle=90,
        shadow=True)

plt.title('Diabetes Outcome Distribution', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
#  2. Feature Distributions (Histograms)

# %%
df.hist(figsize=(14, 10), bins=20, color='steelblue', edgecolor='black')
plt.suptitle('Distribution of All Features', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f',
            linewidths=0.5,
            square=True)
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
features = ['Glucose', 'BMI', 'Age', 'BloodPressure', 'Insulin']

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for i, col in enumerate(features):
    sns.boxplot(x='Outcome', y=col, data=df,
                palette='Set2', ax=axes[i])
    axes[i].set_title(f'{col} by Outcome')
    axes[i].set_xticks([0, 1])
    axes[i].set_xticklabels(['Non-Diabetic', 'Diabetic'])

# Hide the unused 6th subplot
axes[5].set_visible(False)
plt.suptitle('Feature Distribution by Diabetes Outcome', fontsize=16)
plt.tight_layout()
plt.show()
